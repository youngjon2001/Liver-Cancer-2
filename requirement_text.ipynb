# %% [markdown]
# <a href="https://colab.research.google.com/github/youngjon2001/Liver-Cancer-2/blob/main/requirement_text.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data handling
# pandas==2.1.0
# numpy==1.26.0
#
# # Machine learning
# scikit-learn==1.3.2
# catboost==1.2.2
#
# # Model explainability
# shap==1.47.0
#
# # Visualization
# matplotlib==3.8.0
# seaborn==0.12.3
#
# # Notebook
# jupyter==1.0.0
